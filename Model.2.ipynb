# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %% [markdown]
# Collect Data + Preprocess Data

# %%
tickers = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0][['Symbol', 'GICS Sector']]
tickers['Symbol'] = tickers['Symbol'].str.replace('.', '-')
sector_breakdown = tickers.groupby('GICS Sector')['Symbol'].apply(list)
sector_breakdown = sector_breakdown.to_dict()

# Print the sector breakdown
print(sector_breakdown)
# Out:
# {'Communication Services': ['GOOGL', 'GOOG', 'T', 'CHTR', 'CMCSA', 'DIS', 'EA', 'FOXA', 'FOX', 'IPG', 'LYV', 'MTCH', 'META', 'NFLX', 'NWSA', 'NWS', 'OMC', 'PARA', 'TMUS', 'TTWO', 'VZ', 'WBD'], 'Consumer Discretionary': ['ABNB', 'AMZN', 'APTV', 'AZO', 'BBWI', 'BBY', 'BKNG', 'BWA', 'CZR', 'KMX', 'CCL', 'CMG', 'DHI', 'DRI', 'DPZ', 'EBAY', 'ETSY', 'EXPE', 'F', 'GRMN', 'GM', 'GPC', 'HAS', 'HLT', 'HD', 'LVS', 'LEN', 'LKQ', 'LOW', 'LULU', 'MAR', 'MCD', 'MGM', 'MHK', 'NKE', 'NCLH', 'NVR', 'ORLY', 'POOL', 'PHM', 'RL', 'ROST', 'RCL', 'SBUX', 'TPR', 'TSLA', 'TJX', 'TSCO', 'ULTA', 'VFC', 'WHR', 'WYNN', 'YUM'], 'Consumer Staples': ['ADM', 'MO', 'BF-B', 'BG', 'CPB', 'CHD', 'CLX', 'KO', 'CL', 'CAG', 'STZ', 'COST', 'DG', 'DLTR', 'EL', 'GIS', 'HSY', 'HRL', 'K', 'KVUE', 'KDP', 'KMB', 'KHC', 'KR', 'LW', 'MKC', 'TAP', 'MDLZ', 'MNST', 'PEP', 'PM', 'PG', 'SJM', 'SYY', 'TGT', 'TSN', 'WBA', 'WMT'], 'Energy': ['APA', 'BKR', 'CVX', 'COP', 'CTRA', 'DVN', 'FANG', 'EOG', 'EQT', 'XOM', 'HAL', 'HES', 'KMI', 'MRO', 'MPC', 'OXY', 'OKE', 'PSX', 'PXD', 'SLB', 'TRGP', 'VLO', 'WMB'], 'Financials': ['AFL', 'ALL', 'AXP', 'AIG', 'AMP', 'AON', 'ACGL', 'AJG', 'AIZ', 'BAC', 'WRB', 'BRK-B', 'BLK', 'BX', 'BK', 'BRO', 'COF', 'CBOE', 'SCHW', 'CB', 'CINF', 'C', 'CFG', 'CME', 'CMA', 'DFS', 'EG', 'FDS', 'FITB', 'FIS', 'FI', 'FLT', 'BEN', 'GL', 'GPN', 'GS', 'HIG', 'HBAN', 'ICE', 'IVZ', 'JKHY', 'JPM', 'KEY', 'L', 'MTB', 'MKTX', 'MMC', 'MA', 'MET', 'MCO', 'MS', 'MSCI', 'NDAQ', 'NTRS', 'PYPL', 'PNC', 'PFG', 'PGR', 'PRU', 'RJF', 'RF', 'SPGI', 'STT', 'SYF', 'TROW', 'TRV', 'TFC', 'USB', 'V', 'WFC', 'WTW', 'ZION'], 'Health Care': ['ABT', 'ABBV', 'A', 'ALGN', 'AMGN', 'BAX', 'BDX', 'BIO', 'TECH', 'BIIB', 'BSX', 'BMY', 'CAH', 'CTLT', 'COR', 'CNC', 'CRL', 'CI', 'COO', 'CVS', 'DHR', 'DVA', 'XRAY', 'DXCM', 'EW', 'ELV', 'LLY', 'GEHC', 'GILD', 'HCA', 'HSIC', 'HOLX', 'HUM', 'IDXX', 'ILMN', 'INCY', 'PODD', 'ISRG', 'IQV', 'JNJ', 'LH', 'MCK', 'MDT', 'MRK', 'MTD', 'MRNA', 'MOH', 'PFE', 'DGX', 'REGN', 'RMD', 'RVTY', 'STE', 'SYK', 'TFX', 'TMO', 'UNH', 'UHS', 'VRTX', 'VTRS', 'WAT', 'WST', 'ZBH', 'ZTS'], 'Industrials': ['MMM', 'AOS', 'ADP', 'ALK', 'ALLE', 'AAL', 'AME', 'AXON', 'BA', 'BR', 'CHRW', 'CARR', 'CAT', 'CDAY', 'CTAS', 'CPRT', 'CSX', 'CMI', 'DE', 'DAL', 'DOV', 'ETN', 'EMR', 'EFX', 'EXPD', 'FAST', 'FDX', 'FTV', 'GNRC', 'GD', 'GE', 'HON', 'HWM', 'HUBB', 'HII', 'IEX', 'ITW', 'IR', 'JBHT', 'J', 'JCI', 'LHX', 'LDOS', 'LMT', 'MAS', 'NDSN', 'NSC', 'NOC', 'ODFL', 'OTIS', 'PCAR', 'PH', 'PAYX', 'PAYC', 'PNR', 'PWR', 'RTX', 'RSG', 'RHI', 'ROK', 'ROL', 'SNA', 'LUV', 'SWK', 'TXT', 'TT', 'TDG', 'UNP', 'UAL', 'UPS', 'URI', 'VLTO', 'VRSK', 'WAB', 'WM', 'GWW', 'XYL'], 'Information Technology': ['ACN', 'ADBE', 'AKAM', 'AMD', 'APH', 'ADI', 'ANSS', 'AAPL', 'AMAT', 'ANET', 'ADSK', 'AVGO', 'CDNS', 'CDW', 'CSCO', 'CTSH', 'GLW', 'ENPH', 'EPAM', 'FFIV', 'FICO', 'FSLR', 'FTNT', 'IT', 'GEN', 'HPE', 'HPQ', 'IBM', 'INTC', 'INTU', 'JNPR', 'KEYS', 'KLAC', 'LRCX', 'MCHP', 'MU', 'MSFT', 'MPWR', 'MSI', 'NTAP', 'NVDA', 'NXPI', 'ON', 'ORCL', 'PANW', 'PTC', 'QRVO', 'QCOM', 'ROP', 'CRM', 'STX', 'NOW', 'SWKS', 'SEDG', 'SNPS', 'TEL', 'TDY', 'TER', 'TXN', 'TRMB', 'TYL', 'VRSN', 'WDC', 'ZBRA'], 'Materials': ['APD', 'ALB', 'AMCR', 'AVY', 'BALL', 'CE', 'CF', 'CTVA', 'DOW', 'DD', 'EMN', 'ECL', 'FMC', 'FCX', 'IFF', 'IP', 'LIN', 'LYB', 'MLM', 'MOS', 'NEM', 'NUE', 'PKG', 'PPG', 'SEE', 'SHW', 'STLD', 'VMC', 'WRK'], 'Real Estate': ['ARE', 'AMT', 'AVB', 'BXP', 'CPT', 'CBRE', 'CSGP', 'CCI', 'DLR', 'EQIX', 'EQR', 'ESS', 'EXR', 'FRT', 'PEAK', 'HST', 'INVH', 'IRM', 'KIM', 'MAA', 'PLD', 'PSA', 'O', 'REG', 'SBAC', 'SPG', 'UDR', 'VTR', 'VICI', 'WELL', 'WY'], 'Utilities': ['AES', 'LNT', 'AEE', 'AEP', 'AWK', 'ATO', 'CNP', 'CMS', 'ED', 'CEG', 'D', 'DTE', 'DUK', 'EIX', 'ETR', 'EVRG', 'ES', 'EXC', 'FE', 'NEE', 'NI', 'NRG', 'PCG', 'PNW', 'PPL', 'PEG', 'SRE', 'SO', 'WEC', 'XEL']}

# %%
ticker_list = []
for sector in sector_breakdown:
    ticker_list.extend(sector_breakdown[sector])

today = pd.Timestamp.today().strftime('%Y-%m-%d')
month_ago = pd.Timestamp.today() - pd.DateOffset(months=1)

data = yf.download(ticker_list, start=month_ago, end=today)
#data = data.drop(columns=['Open', 'High', 'Low', 'Close', 'Volume'])
data
# Out:
# [*********************100%%**********************]  503 of 503 completed
# 5 Failed downloads:
# ['SJM', 'V', 'TMUS', 'VICI', 'BX']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2023-10-30 02:25:29.664089 -> 2023-11-30)')
#                       Adj Close                                             \
#                               A    AAL        AAPL        ABBV        ABNB
# Date
# 2023-10-30 00:00:00  101.169998  11.18  170.065933  141.889999  116.949997
# 2023-10-31 00:00:00  103.370003  11.15  170.545319  141.179993  118.290001
# 2023-11-01 00:00:00  102.860001  11.14  173.741104  142.470001  119.470001
# 2023-11-02 00:00:00  104.470001  11.40  177.336380  143.259995  115.500000
# 2023-11-03 00:00:00  109.019997  11.98  176.417572  141.419998  122.639999
# 2023-11-06 00:00:00  107.529999  11.66  178.994186  141.199997  118.169998
# 2023-11-07 00:00:00  110.540001  11.75  181.580780  142.160004  121.080002
# 2023-11-08 00:00:00  109.389999  12.01  182.649368  142.029999  117.660004
# 2023-11-09 00:00:00  107.739998  11.75  182.169998  138.039993  115.519997
# 2023-11-10 00:00:00  108.470001  11.80  186.399994  138.589996  118.150002
# 2023-11-13 00:00:00  107.459999  11.78  184.800003  138.639999  119.150002
# 2023-11-14 00:00:00  111.610001  12.25  187.440002  138.059998  126.680000
# 2023-11-15 00:00:00  113.599998  12.42  188.009995  137.600006  128.350006
# 2023-11-16 00:00:00  114.190002  12.19  189.710007  138.279999  126.279999
# 2023-11-17 00:00:00  113.150002  12.29  189.690002  138.300003  127.150002
# 2023-11-20 00:00:00  113.980003  12.40  191.449997  138.309998  129.699997
# 2023-11-21 00:00:00  123.919998  12.13  190.639999  138.729996  126.820000
# 2023-11-22 00:00:00  123.989998  12.31  191.309998  138.470001  129.039993
# 2023-11-24 00:00:00  126.620003  12.31  189.970001  138.669998  128.369995
# 2023-11-27 00:00:00  125.010002  12.18  189.789993  139.089996  129.000000
# 2023-11-28 00:00:00  124.709999  12.17  190.399994  138.080002  127.559998
# 2023-11-29 00:00:00  127.589996  12.23  189.369995  138.500000  126.480003
#
#                                                                     \
#                             ABT       ACGL         ACN        ADBE
# Date
# 2023-10-30 00:00:00   93.000000  82.879997  292.700012  526.940002
# 2023-10-31 00:00:00   94.550003  86.680000  297.089996  532.059998
# 2023-11-01 00:00:00   95.010002  90.000000  300.640015  544.500000
# 2023-11-02 00:00:00   95.959999  85.940002  308.119995  558.710022
# 2023-11-03 00:00:00   95.839996  85.550003  313.489990  563.659973
# 2023-10-31 00:00:00  3449200  2006600  1382000  914200  2387400  3208900
# 2023-11-01 00:00:00  2128900  2788100  1503100  822900  2261800  7269900
# 2023-11-02 00:00:00  1666600  1920500  3030300  758500  3026800  4137800
# 2023-11-03 00:00:00  1852500  1754600  2140100  540800  2598900  1974700
# 2023-11-06 00:00:00  1324300  1537900  2443700  373800  1551900  2112500
# 2023-11-07 00:00:00  1385100  1408000  2699200  613300  1763500  2938200
# 2023-11-08 00:00:00  1062400  1015300  1524700  525900  1755000  3326300
# 2023-11-09 00:00:00  1533100  1096900  1729100  486900  1875000  3479300
# 2023-11-10 00:00:00  1322000  1317200  1965900  602300  1649200  2108500
# 2023-11-13 00:00:00  1261100  1230500  1702200  411200  1240300  1544900
# 2023-11-14 00:00:00  1500400  1353700  1909700  542700  3270200  1421500
# 2023-11-15 00:00:00  1297000  1309400  3648600  501600  2444400  1714100
# 2023-11-16 00:00:00  1314800  1554600  2300700  275700  2217300  1566900
# 2023-11-17 00:00:00  1286600  1089600  2991400  340600  2136200  2425100
# 2023-11-20 00:00:00  1147100   915000  1345100  330600  1589000  1056700
# 2023-11-21 00:00:00  1353600   983700  1629300  360500  2311600  1423800
# 2023-11-22 00:00:00  1627700   980600  1246200  550100  1441300  1501500
# 2023-11-24 00:00:00   797400   555600   605500  195200   584000   635200
# 2023-11-27 00:00:00  1058800  1143800  1301400  528600  1424200  1442700
# 2023-11-28 00:00:00  1293400  1392800  1212800  424900  1922800  1348900
# 2023-11-29 00:00:00  1184100  1240100  1311200  372900  2755200  1524400
#
# [22 rows x 3018 columns]

# %%
# Backward fill NaN values
data = data.fillna(method='bfill', axis=0)

# Backward fill NaN values
data = data.fillna(method='ffill', axis=0)

# Print number of NA values across each column
print(data.isna().sum(axis=1))
# Out:
# Date
# 2023-10-30 00:00:00    30
# 2023-10-31 00:00:00    30
# 2023-11-01 00:00:00    30
# 2023-11-02 00:00:00    30
# 2023-11-03 00:00:00    30
# 2023-11-06 00:00:00    30
# 2023-11-07 00:00:00    30
# 2023-11-08 00:00:00    30
# 2023-11-09 00:00:00    30
# 2023-11-10 00:00:00    30
# 2023-11-13 00:00:00    30
# 2023-11-14 00:00:00    30
# 2023-11-15 00:00:00    30
# 2023-11-16 00:00:00    30
# 2023-11-17 00:00:00    30
# 2023-11-20 00:00:00    30
# 2023-11-21 00:00:00    30
# 2023-11-22 00:00:00    30
# 2023-11-24 00:00:00    30
# 2023-11-27 00:00:00    30
# 2023-11-28 00:00:00    30
# 2023-11-29 00:00:00    30
# dtype: int64
# C:\Users\ayush\AppData\Local\Temp\ipykernel_27348\1922356623.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data = data.fillna(method='bfill', axis=0)
# C:\Users\ayush\AppData\Local\Temp\ipykernel_27348\1922356623.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data = data.fillna(method='ffill', axis=0)

# %%
# Calculate daily returns
returns = data.pct_change()

# Drop the index name Adj Close
returns = returns.droplevel(0, axis=1)

# Group tickers in returns dataframe by sector using sector_breakdown's keys & values
sector_mean_returns = {}

# Extract each key & value pair from sector_breakdown
for sector, tickers in sector_breakdown.items():
    # Get tickers for each sector
    sector_data = returns[tickers]

    # Calculate mean returns for each sector and add to dictionary
    sector_mean_returns[sector] = sector_data.mean(axis=1)

# Convert sector_mean_returns dict to a DataFrame
sector_mean_returns = pd.DataFrame(sector_mean_returns)

sector_mean_returns
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_27348\677370838.py:2: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version.
# Health Care                0.003585                0.003364   0.004972
# Industrials                0.003669                0.003244   0.004685
# Information Technology     0.003244                0.003197   0.004266
# Materials                  0.004685                0.004266   0.006868
# Real Estate                0.005010                0.004697   0.006670
# Utilities                  0.004294                0.003885   0.005735
#
#                         Real Estate  Utilities
# Communication Services     0.005332   0.004721
# Consumer Discretionary     0.005543   0.004527
# Consumer Staples           0.004461   0.004102
# Energy                     0.003995   0.003490
# Financials                 0.005778   0.004599
# Health Care                0.005123   0.004359
# Industrials                0.005010   0.004294
# Information Technology     0.004697   0.003885
# Materials                  0.006670   0.005735
# Real Estate                0.007764   0.005993
# Utilities                  0.005993   0.005386

# %% [markdown]
# Black-Litterman Model

# %%
class BlackLittermanModel:
    def __init__(self, market_equilibrium_returns, covariance_matrix, views, confidence_matrix):
        self.market_equilibrium_returns = market_equilibrium_returns
        self.covariance_matrix = covariance_matrix
        self.views = views
        self.confidence_matrix = confidence_matrix

    def calculate_bl_expected_returns(self):
        """
        Calculate expected returns using the Black-Litterman model.
        """
        tau = 0.025  # Tau is the scaling factor, adjust as needed

        # Calculate the equilibrium excess returns
        pi = np.dot(self.covariance_matrix, self.market_equilibrium_returns)

        # Calculate the Black-Litterman expected returns
        bl_expected_returns = np.dot(
            np.linalg.inv(np.linalg.inv(tau * self.covariance_matrix) + np.dot(np.dot(self.views.T, np.linalg.inv(self.confidence_matrix)), self.views)),
            np.dot(np.linalg.inv(tau * self.covariance_matrix), pi) + np.dot(np.dot(self.views.T, np.linalg.inv(self.confidence_matrix)), self.views.T.dot(self.views.dot(self.market_equilibrium_returns)))
        )

        return bl_expected_returns

# %%
# Assuming you have a risk-free rate and equity risk premium
risk_free_rate = 0.047  # Adjust based on the current risk-free rate
equity_risk_premium = 0.06  # Adjust based on economic indicators

# Calculate market equilibrium returns
market_equilibrium_returns = risk_free_rate + equity_risk_premium + sector_mean_returns.mean(axis=0)

# Print the market equilibrium returns
print("Market Equilibrium Returns:")
print(market_equilibrium_returns)
# Out:
# Market Equilibrium Returns:
# Communication Services    0.127870
# Consumer Discretionary    0.127543
# Consumer Staples          0.123523
# Energy                    0.119987
# Financials                0.125910
# Health Care               0.126744
# Industrials               0.125425
# Information Technology    0.126551
# Materials                 0.128964
# Real Estate               0.129524
# Utilities                 0.127757
# dtype: float64

# %%
# Define the sectors in your portfolio
sectors = [
    'Communication Services',
    'Consumer Discretionary',
    'Consumer Staples',
    'Energy',
    'Financials',
    'Health Care',
    'Industrials',
    'Information Technology',
    'Materials',
    'Real Estate',
    'Utilities'
]

# Assuming you have len(sectors) assets in your portfolio
n_assets = len(sectors)

# Define your views based on your analysis
views = np.zeros(n_assets)

# Replace the values below with your own views for each sector
views[0] = 0.02  # Positive view on Communication Services
views[1] = -0.01  # Negative view on Consumer Discretionary
views[2] = 0.015   # Positive view on Consumer Staples
views[3] = -0.02  # Negative view on Energy
views[4] = 0.01  # Positive view on Financials
views[5] = 0.005  # Slightly positive view on Health Care
views[6] = -0.015  # Negative view on Industrials
views[7] = 0.03  # Positive view on Information Technology
views[8] = -0.01  # Negative view on Materials
views[9] = 0.005  # Slightly positive view on Real Estate
views[10] = -0.02  # Negative view on Utilities

print("Your Views:")
print(views)

# Ensure that the sum of views is zero for market equilibrium
views = views - np.mean(views)
print("Adjusted Views:")
print(views)

# Define confidence levels for each view
confidence_levels = {
    'Communication Services': 0.09,
    'Consumer Discretionary': 0.09,
    'Consumer Staples': 0.09,
    'Energy': 0.09,
    'Financials': 0.09,
    'Health Care': 0.09,
    'Industrials': 0.09,
    'Information Technology': 0.09,
    'Materials': 0.09,
    'Real Estate': 0.09,
    'Utilities': 0.09,
}

# Create a diagonal matrix using the confidence levels
confidence_matrix = np.diag([confidence_levels[sectors[i]] for i in range(n_assets)])
# Out:
# Your Views:
# [ 0.02  -0.01   0.015 -0.02   0.01   0.005 -0.015  0.03  -0.01   0.005
#  -0.02 ]
# Adjusted Views:
# [ 0.01909091 -0.01090909  0.01409091 -0.02090909  0.00909091  0.00409091
#  -0.01590909  0.02909091 -0.01090909  0.00409091 -0.02090909]

# %%
# Assuming you have market_equilibrium_returns, covariance_matrix, investor_views, and confidence_matrix defined
bl_model = BlackLittermanModel(market_equilibrium_returns, cov_matrix, views, confidence_matrix)
bl_expected_returns = bl_model.calculate_bl_expected_returns()

# Print the Black-Litterman expected returns
print("Black-Litterman Expected Returns:")
print(bl_expected_returns)
# Out:
# Black-Litterman Expected Returns:
# [0.00581976 0.00579178 0.00497619 0.00447063 0.0058503  0.0055531
#  0.0053194  0.00497208 0.00714946 0.00764714 0.0064695 ]

# %% [markdown]
# LSTM Model

# %%
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
# Out:
# WARNING:tensorflow:From C:\Users\ayush\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def create_sequences(data, sequence_length):
    """
    Create input sequences for LSTM model.

    Parameters:
    - data: numpy array, input data (scaled returns)
    - sequence_length: int, length of each sequence

    Returns:
    - X: numpy array, input sequences
    - y: numpy array, corresponding output values
    """
    X, y = [], []

    for i in range(len(data) - sequence_length):
        sequence = data[i:i + sequence_length]
        target = data[i + sequence_length]
        X.append(sequence)
        y.append(target)

    return np.array(X), np.array(y)

# %%
# Assuming you have already calculated mean_returns
equilibrium_expected_returns = risk_free_rate + equity_risk_premium + sector_mean_returns.mean(axis=0)

# Print Equilibrium Expected Returns
print("Equilibrium Expected Returns:")
print(equilibrium_expected_returns)

# Assuming you have already loaded the data and calculated returns
cov_matrix = sector_mean_returns.cov()

# Print Covariance Matrix
print("Covariance Matrix:")
print(cov_matrix)

# LSTM-based Portfolio Optimization

# Prepare data for LSTM
returns_data = sector_mean_returns[sectors].copy()
scaler_lstm = MinMaxScaler(feature_range=(0, 1))
scaled_returns_data = scaler_lstm.fit_transform(returns_data)

# Create input sequences for LSTM
sequence_length_lstm = 10
sequences_lstm, targets_lstm = create_sequences(scaled_returns_data, sequence_length_lstm)

# Split data into train and test sets
train_size_lstm = int(len(sequences_lstm) * 0.8)
train_lstm, test_lstm = sequences_lstm[:train_size_lstm], sequences_lstm[train_size_lstm:]
train_targets, test_targets = targets_lstm[:train_size_lstm], targets_lstm[train_size_lstm:]

# Extract features (X) and target variable (y) for LSTM
X_train_lstm, y_train_lstm = train_lstm[:, :-1, :], train_targets
X_test_lstm, y_test_lstm = test_lstm[:, :-1, :], test_targets

# Reshape input data for LSTM (batch_size, time_steps, features)
X_train_lstm = np.reshape(X_train_lstm, (X_train_lstm.shape[0], X_train_lstm.shape[1], X_train_lstm.shape[2]))
X_test_lstm = np.reshape(X_test_lstm, (X_test_lstm.shape[0], X_test_lstm.shape[1], X_test_lstm.shape[2]))

print("X_train_lstm shape:", X_train_lstm.shape)
print("y_train_lstm shape:", y_train_lstm.shape)
# Out:
# Equilibrium Expected Returns:
# Communication Services    0.127870
# Consumer Discretionary    0.127543
# Consumer Staples          0.123523
# Energy                    0.119987
# Financials                0.125910
# Health Care               0.126744
# Industrials               0.125425
# Information Technology    0.126551
# Materials                 0.128964
# Real Estate               0.129524
# Utilities                 0.127757
# dtype: float64
# Covariance Matrix:
#                         Communication Services  Consumer Discretionary  \
# Communication Services                0.004665                0.004046
# Consumer Discretionary                0.004046                0.004306
# Consumer Staples                      0.003683                0.003424
# Energy                                0.003201                0.003245
# Financials                            0.004090                0.004290
# Health Care                           0.003880                0.003997
# Industrials                           0.003731                0.003779
# Information Technology                0.003544                0.003643
# Materials                             0.005067                0.004941
# Real Estate                           0.005332                0.005543
# Utilities                             0.004721                0.004527
#
#                         Consumer Staples    Energy  Financials  Health Care  \
# Communication Services          0.003683  0.003201    0.004090     0.003880
# Consumer Discretionary          0.003424  0.003245    0.004290     0.003997
# Consumer Staples                0.003352  0.002653    0.003487     0.003467
# Energy                          0.002653  0.003050    0.003072     0.003108
# Financials                      0.003487  0.003072    0.004450     0.003939
# Health Care                     0.003467  0.003108    0.003939     0.004064
# Industrials                     0.003312  0.002832    0.003866     0.003585
# Information Technology          0.002950  0.002839    0.003641     0.003364
# Materials                       0.004413  0.003853    0.004978     0.004972
# Real Estate                     0.004461  0.003995    0.005778     0.005123
# Utilities                       0.004102  0.003490    0.004599     0.004359
#
#                         Industrials  Information Technology  Materials  \
# Communication Services     0.003731                0.003544   0.005067
# Consumer Discretionary     0.003779                0.003643   0.004941
# Consumer Staples           0.003312                0.002950   0.004413
# Energy                     0.002832                0.002839   0.003853
# Financials                 0.003866                0.003641   0.004978
# Health Care                0.003585                0.003364   0.004972
# Industrials                0.003669                0.003244   0.004685
# Information Technology     0.003244                0.003197   0.004266
# Materials                  0.004685                0.004266   0.006868
# Real Estate                0.005010                0.004697   0.006670
# Utilities                  0.004294                0.003885   0.005735
#
#                         Real Estate  Utilities
# Communication Services     0.005332   0.004721
# Consumer Discretionary     0.005543   0.004527
# Consumer Staples           0.004461   0.004102
# Energy                     0.003995   0.003490
# Financials                 0.005778   0.004599
# Health Care                0.005123   0.004359
# Industrials                0.005010   0.004294
# Information Technology     0.004697   0.003885
# Materials                  0.006670   0.005735
# Real Estate                0.007764   0.005993
# Utilities                  0.005993   0.005386
# X_train_lstm shape: (8, 9, 11)
# y_train_lstm shape: (8, 11)

# %%
# Build a separate LSTM model for each sector
models_lstm = []
predictions_lstm = []

for i in range(len(sectors)):
    # Build LSTM model
    model_lstm = Sequential()
    model_lstm.add(LSTM(units=50, return_sequences=True, input_shape=(X_train_lstm.shape[1], X_train_lstm.shape[2])))
    model_lstm.add(LSTM(units=50))
    model_lstm.add(Dense(units=1))
    model_lstm.compile(optimizer='adam', loss='mean_squared_error')

    # Train the LSTM model
    model_lstm.fit(X_train_lstm, y_train_lstm[:, i], epochs=10, batch_size=32)

    # Make predictions on the test set
    predictions_sector = model_lstm.predict(X_test_lstm)
    predictions_lstm.append(predictions_sector)

    # Save the model for each sector
    models_lstm.append(model_lstm)
# Out:
# Epoch 1/10
# 1/1 [==============================] - 5s 5s/step - loss: 0.0875
# Epoch 2/10
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0522
# Epoch 3/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0294
# Epoch 4/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0181
# Epoch 5/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0169
# Epoch 6/10
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0222
# Epoch 7/10
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0273
# Epoch 8/10
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0285
# Epoch 9/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0263
# Epoch 10/10
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0227
# 1/1 [==============================] - 1s 706ms/step
# Epoch 1/10
# 1/1 [==============================] - 3s 3s/step - loss: 0.1283
# Epoch 2/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0859
# Epoch 3/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0554
# Epoch 4/10
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0354
# Epoch 5/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0248
# Epoch 6/10
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0226
# Epoch 7/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0266
# Epoch 8/10
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0325
# Epoch 9/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0360
# Epoch 10/10
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0358
# 1/1 [==============================] - 1s 711ms/step
# Epoch 1/10
# 1/1 [==============================] - 3s 3s/step - loss: 0.0812
# Epoch 2/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0504
# Epoch 3/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0287
# Epoch 4/10
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0163
# Epoch 5/10
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0134
# Epoch 6/10
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0181
# Epoch 7/10
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0239
# Epoch 8/10
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0255
# Epoch 9/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0233
# Epoch 10/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0196
# 1/1 [==============================] - 1s 730ms/step
# Epoch 1/10
# 1/1 [==============================] - 3s 3s/step - loss: 0.1189
# Epoch 2/10
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0829
# Epoch 3/10
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0548
# Epoch 4/10
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0345
# Epoch 5/10
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0224
# Epoch 6/10
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0189
# Epoch 7/10
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0228
# Epoch 8/10
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0294
# Epoch 9/10
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0332
# Epoch 10/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0328
# 1/1 [==============================] - 1s 710ms/step
# Epoch 1/10
# 1/1 [==============================] - 3s 3s/step - loss: 0.1062
# Epoch 2/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0741
# Epoch 3/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0508
# Epoch 4/10
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0357
# Epoch 5/10
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0282
# Epoch 6/10
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0278
# Epoch 7/10
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0322
# Epoch 8/10
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0369
# Epoch 9/10
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0387
# Epoch 10/10
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0375
# 1/1 [==============================] - 1s 715ms/step
# Epoch 1/10
# 1/1 [==============================] - 3s 3s/step - loss: 0.0654
# Epoch 2/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0358
# Epoch 3/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0181
# Epoch 4/10
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0119
# Epoch 5/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0151
# Epoch 6/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0210
# Epoch 7/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0233
# Epoch 8/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0214
# Epoch 9/10
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0179
# Epoch 10/10
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0145
# 1/1 [==============================] - 1s 731ms/step
# Epoch 1/10
# 1/1 [==============================] - 3s 3s/step - loss: 0.1256
# Epoch 2/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0900
# Epoch 3/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0624
# Epoch 4/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0416
# Epoch 5/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0273
# Epoch 6/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0195
# Epoch 7/10
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0181
# Epoch 8/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0220
# Epoch 9/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0273
# Epoch 10/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0302
# 1/1 [==============================] - 1s 713ms/step
# Epoch 1/10
# 1/1 [==============================] - 3s 3s/step - loss: 0.0957
# Epoch 2/10
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0671
# Epoch 3/10
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0457
# Epoch 4/10
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0310
# Epoch 5/10
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0234
# Epoch 6/10
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0227
# Epoch 7/10
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0272
# Epoch 8/10
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0318
# Epoch 9/10
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0329
# Epoch 10/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0309
# 1/1 [==============================] - 1s 719ms/step
# Epoch 1/10
# 1/1 [==============================] - 3s 3s/step - loss: 0.0328
# Epoch 2/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0153
# Epoch 3/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0077
# Epoch 4/10
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0085
# Epoch 5/10
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0124
# Epoch 6/10
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0139
# Epoch 7/10
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0126
# Epoch 8/10
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0103
# Epoch 9/10
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0083
# Epoch 10/10
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0073
# 1/1 [==============================] - 1s 682ms/step
# Epoch 1/10
# 1/1 [==============================] - 3s 3s/step - loss: 0.0837
# Epoch 2/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0553
# Epoch 3/10
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0369
# Epoch 4/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0278
# Epoch 5/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0267
# Epoch 6/10
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0310
# Epoch 7/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0353
# Epoch 8/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0365
# Epoch 9/10
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0348
# Epoch 10/10
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0320
# 1/1 [==============================] - 1s 735ms/step
# Epoch 1/10
# 1/1 [==============================] - 3s 3s/step - loss: 0.0443
# Epoch 2/10
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0268
# Epoch 3/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0162
# Epoch 4/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0122
# Epoch 5/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0140
# Epoch 6/10
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0176
# Epoch 7/10
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0190
# Epoch 8/10
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0178
# Epoch 9/10
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0155
# Epoch 10/10
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0135
# 1/1 [==============================] - 1s 780ms/step

# %%
# Convert predictions list to numpy array
predictions_lstm = np.array(predictions_lstm)

# Reshape predictions back to the original shape
predictions_lstm = np.reshape(predictions_lstm, (predictions_lstm.shape[1], predictions_lstm.shape[0]))

# Inverse transform the predictions using the scaler
predicted_returns_lstm = scaler_lstm.inverse_transform(predictions_lstm)

# Reshape back to the original shape
predicted_returns_lstm = np.reshape(predicted_returns_lstm, (predicted_returns_lstm.shape[0], len(sectors)))

# Print the predicted returns for each sector
for i, sector in enumerate(sectors):
    print(f"Predicted Returns for {sector}:")
    print(predicted_returns_lstm[:, i])
# Out:
# Predicted Returns for Communication Services:
# [0.02434757 0.05613302 0.03921209]
# Predicted Returns for Consumer Discretionary:
# [0.01357014 0.02432707 0.0434005 ]
# Predicted Returns for Consumer Staples:
# [ 0.01719658  0.01319217 -0.03234709]
# Predicted Returns for Energy:
# [ 0.01813755  0.01285798 -0.03731747]
# Predicted Returns for Financials:
# [ 0.03060976  0.00158547 -0.02581918]
# Predicted Returns for Health Care:
# [0.04559514 0.00140647 0.00863026]
# Predicted Returns for Industrials:
# [ 0.01003616 -0.00820204 -0.01337863]
# Predicted Returns for Information Technology:
# [ 0.00157515  0.0296284  -0.00968123]
# Predicted Returns for Materials:
# [0.06229734 0.08437207 0.02964238]
# Predicted Returns for Real Estate:
# [0.07615241 0.08375987 0.01355051]
# Predicted Returns for Utilities:
# [0.04883568 0.05304671 0.00580595]

# %%
# Initialize an empty dictionary to store combined expected returns for each sector
combined_expected_returns_by_sector = {}
weight_lstm = 0.2

# Iterate through each sector
for sector in sectors:
    # Equilibrium expected returns for the current sector
    equilibrium_expected_returns_sector = equilibrium_expected_returns[sector]

    try:
        # LSTM predictions for the current sector
        predicted_returns_lstm_sector = predicted_returns_lstm[sectors.index(sector)]
    except IndexError:
        print(f"Skipping {sector} because it doesn't have LSTM predictions.")
        continue

    # Combine expected returns for the current sector
    combined_expected_returns_sector = equilibrium_expected_returns_sector + weight_lstm * predicted_returns_lstm_sector

    # Store the combined expected returns for the current sector
    combined_expected_returns_by_sector[sector] = combined_expected_returns_sector

# Print the combined expected returns for each sector
for sector, combined_returns in combined_expected_returns_by_sector.items():
    print(f"Combined Expected Returns for {sector}:")
    print(combined_returns)
    print()
# Out:
# Skipping Energy because it doesn't have LSTM predictions.
# Skipping Financials because it doesn't have LSTM predictions.
# Skipping Health Care because it doesn't have LSTM predictions.
# Skipping Industrials because it doesn't have LSTM predictions.
# Skipping Information Technology because it doesn't have LSTM predictions.
# Skipping Materials because it doesn't have LSTM predictions.
# Skipping Real Estate because it doesn't have LSTM predictions.
# Skipping Utilities because it doesn't have LSTM predictions.
# Combined Expected Returns for Communication Services:
# [0.13273974 0.13058424 0.13130954 0.13149773 0.13399217 0.13698925
#  0.12987745 0.12818524 0.14032969 0.1431007  0.13763735]
#
# Combined Expected Returns for Consumer Discretionary:
# [0.13877001 0.13240881 0.13018183 0.130115   0.1278605  0.1278247
#  0.125903   0.13346909 0.14441782 0.14429538 0.13815275]
#
# Combined Expected Returns for Consumer Staples:
# [0.13136551 0.13220319 0.11705367 0.1160596  0.11835926 0.12524915
#  0.12084737 0.12158684 0.12945157 0.12623319 0.12468428]

# %% [markdown]
# Combine Black-Litterman and LSTM

# %%
# Assuming you have already calculated mean_returns for the LSTM predictions
equilibrium_expected_returns_lstm = risk_free_rate + equity_risk_premium + predicted_returns_lstm.mean(axis=0)

# Assuming you have already loaded the data and calculated returns for the LSTM predictions
cov_matrix_lstm = np.cov(predicted_returns_lstm, rowvar=False)

# Align LSTM predictions with sectors
aligned_predicted_returns_lstm = np.zeros(len(sectors))
for i in range(len(sectors)):
    if i < len(predicted_returns_lstm):
        # Take the average of the predictions for the current sector
        aligned_predicted_returns_lstm[i] = np.mean(predicted_returns_lstm[i])
    else:
        # Handle the case when the sector is not present in LSTM predictions
        print(f"Skipping {sectors[i]} because it doesn't have LSTM predictions.")
        aligned_predicted_returns_lstm[i] = 0  # You can set a default value or handle it differently

# Combine Expected Returns
combined_expected_returns = equilibrium_expected_returns + weight_lstm * aligned_predicted_returns_lstm

# Print Combined Expected Returns
print("Combined Expected Returns:")
print(combined_expected_returns)
# Out:
# Skipping Energy because it doesn't have LSTM predictions.
# Skipping Financials because it doesn't have LSTM predictions.
# Skipping Health Care because it doesn't have LSTM predictions.
# Skipping Industrials because it doesn't have LSTM predictions.
# Skipping Information Technology because it doesn't have LSTM predictions.
# Skipping Materials because it doesn't have LSTM predictions.
# Skipping Real Estate because it doesn't have LSTM predictions.
# Skipping Utilities because it doesn't have LSTM predictions.
# Combined Expected Returns:
# Communication Services    0.134204
# Consumer Discretionary    0.133945
# Consumer Staples          0.123918
# Energy                    0.119987
# Financials                0.125910
# Health Care               0.126744
# Industrials               0.125425
# Information Technology    0.126551
# Materials                 0.128964
# Real Estate               0.129524
# Utilities                 0.127757
# dtype: float64

# %%
# Combine Covariance Matrices
combined_cov_matrix = (1 - weight_lstm) * cov_matrix + weight_lstm * cov_matrix_lstm

combined_cov_matrix
# Out:
#                         Communication Services  Consumer Discretionary  \
# Communication Services                0.003782                0.003252
# Consumer Discretionary                0.003252                0.003491
# Consumer Staples                      0.002943                0.002660
# Energy                                0.002556                0.002507
# Financials                            0.003228                0.003348
# Health Care                           0.003035                0.003149
# Industrials                           0.002957                0.002990
# Information Technology                0.002882                0.002889
# Materials                             0.004092                0.003893
# Real Estate                           0.004283                0.004330
# Utilities                             0.003787                0.003551
#
#                         Consumer Staples    Energy  Financials  Health Care  \
# Communication Services          0.002943  0.002556    0.003228     0.003035
# Consumer Discretionary          0.002660  0.002507    0.003348     0.003149
# Consumer Staples                0.002833  0.002291    0.002928     0.002830
# Energy                          0.002291  0.002627    0.002613     0.002551
# Financials                      0.002928  0.002613    0.003720     0.003257
# Health Care                     0.002830  0.002551    0.003257     0.003364
# Industrials                     0.002698  0.002321    0.003159     0.002922
# Information Technology          0.002435  0.002353    0.002943     0.002654
# Materials                       0.003665  0.003231    0.004072     0.003972
# Real Estate                     0.003778  0.003428    0.004797     0.004148
# Utilities                       0.003424  0.002950    0.003799     0.003522
#
#                         Industrials  Information Technology  Materials  \
# Communication Services     0.002957                0.002882   0.004092
# Consumer Discretionary     0.002990                0.002889   0.003893
# Consumer Staples           0.002698                0.002435   0.003665
# Energy                     0.002321                0.002353   0.003231
# Financials                 0.003159                0.002943   0.004072
# Health Care                0.002922                0.002654   0.003972
# Industrials                0.002965                0.002594   0.003770
# Information Technology     0.002594                0.002640   0.003517
# Materials                  0.003770                0.003517   0.005646
# Real Estate                0.004064                0.003880   0.005538
# Utilities                  0.003474                0.003190   0.004724
#
#                         Real Estate  Utilities
# Communication Services     0.004283   0.003787
# Consumer Discretionary     0.004330   0.003551
# Consumer Staples           0.003778   0.003424
# Energy                     0.003428   0.002950
# Financials                 0.004797   0.003799
# Health Care                0.004148   0.003522
# Industrials                0.004064   0.003474
# Information Technology     0.003880   0.003190
# Materials                  0.005538   0.004724
# Real Estate                0.006508   0.004996
# Utilities                  0.004996   0.004446

# %% [markdown]
# Calculate Allocations

# %%
# Calculate the inverse of the combined covariance matrix
inv_combined_cov_matrix = np.linalg.inv(combined_cov_matrix)

# Calculate the expected excess returns
expected_excess_returns = combined_expected_returns

# Calculate the Black-Litterman expected returns
bl_expected_returns = np.dot(inv_combined_cov_matrix, expected_excess_returns)

# Normalize weights to get allocations
allocations = bl_expected_returns / np.sum(bl_expected_returns)

# Make sure allocations are non-negative
allocations[allocations < 0] = 0

# Normalize again to ensure the sum is 1
allocations /= np.sum(allocations)


# Print the allocations for each sector
for sector, allocation in zip(sectors, allocations):
    print(f"Allocation for {sector}: {allocation:.4f}")
# Out:
# Allocation for Communication Services: 0.0296
# Allocation for Consumer Discretionary: 0.0127
# Allocation for Consumer Staples: 0.2933
# Allocation for Energy: 0.0611
# Allocation for Financials: 0.1470
# Allocation for Health Care: 0.0000
# Allocation for Industrials: 0.1871
# Allocation for Information Technology: 0.2691
# Allocation for Materials: 0.0000
# Allocation for Real Estate: 0.0000
# Allocation for Utilities: 0.0000

# %% [markdown]
#  Evaluate Portfolio Performance

# %%
def evaluate_portfolio(returns, weights):
    # Calculate annualized portfolio return
    annual_portfolio_return = np.sum(returns.mean() * weights) * 252

    # Calculate annualized portfolio volatility
    portfolio_volatility = np.sqrt(np.dot(weights.T, np.dot(returns.cov() * 252, weights)))

    # Assuming risk-free rate is 0 for simplicity
    risk_free_rate = 0

    # Calculate Sharpe ratio
    sharpe_ratio = (annual_portfolio_return - risk_free_rate) / portfolio_volatility

    return annual_portfolio_return, portfolio_volatility, sharpe_ratio

# Assuming you have a DataFrame 'returns_data' containing returns for each sector
# Assuming 'allocations' contains the weights/allocations for each sector

# Evaluate portfolio performance
portfolio_return, portfolio_volatility, sharpe_ratio = evaluate_portfolio(returns_data, allocations)

# Print the results
print(f"Annual Portfolio Return: {portfolio_return:.4f}")
print(f"Annual Portfolio Volatility: {portfolio_volatility:.4f}")
print(f"Sharpe Ratio: {sharpe_ratio:.4f}")
# Out:
# Annual Portfolio Return: 4.5382
# Annual Portfolio Volatility: 0.9158
# Sharpe Ratio: 4.9552
